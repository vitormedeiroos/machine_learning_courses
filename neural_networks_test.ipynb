# %% [markdown]
# <a href="https://colab.research.google.com/github/VituMacedoo/Machine-Learning-/blob/main/neural_networks_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5 # clone
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# %cd yolov5

# %%
# %pip install -qr requirements.txt # install #torch #utils
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.6 MB/s eta 0:00:00

# %%
import torch
import utils

# %%
display = utils.notebook_init() # checks
# Out:
# YOLOv5 🚀 v7.0-162-gc3e4e94 Python-3.10.11 torch-2.0.0+cu118 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.4/107.7 GB disk)

# %%
# !unzip -q /content/cachorro_set.zip -d /content/.

# %%
# !chmod -R 777 /content/cachorro_set.zip
# !chmod 777 /content/yolov5/data/cachorro.yaml

# %%
# !python /content/yolov5/train.py --img 416 --batch 16 --epochs 300 --data cachorro.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=cachorro.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-162-gc3e4e94 Python-3.10.11 torch-2.0.0+cu118 CPU
#
# ...

# %%
# !python /content/yolov5/detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 416 --conf 0.25 --source /datalab/cachorro_teste\ \(1\).jpg  

#ajustar caminho
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/datalab/cachorro_teste (1).jpg, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-162-gc3e4e94 Python-3.10.11 torch-2.0.0+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /datalab/cachorro_teste (1).jpg: 416x416 1 Cachorro, 205.6ms
# Speed: 4.8ms pre-process, 205.6ms inference, 1.1ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/exp

# %%
from PIL import Image

# creating a object
im = Image.open('/content/yolov5/runs/detect/exp/cachorro_teste (1).jpg')
  
im.show()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=416x416 at 0x7F48AEB83E80>

# %%
# !python /content/yolov5/detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 416 --conf 0.25 --source /datalab/web/cachorro_teste\ \(2\).jpg  

#ajustar caminho
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/datalab/web/cachorro_teste (2).jpg, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-162-gc3e4e94 Python-3.10.11 torch-2.0.0+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /datalab/web/cachorro_teste (2).jpg: 416x416 1 Cachorro, 195.4ms
# Speed: 4.0ms pre-process, 195.4ms inference, 1.4ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/exp2

# %%
im_2 = Image.open('/content/yolov5/runs/detect/exp2/cachorro_teste (2).jpg')
  
im_2.show()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=416x416 at 0x7F48AEACDD80>

# %%
# !python /content/yolov5/detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 416 --conf 0.25 --source /datalab/web/cachorro_teste\ \(3\).jpg  

#ajustar caminho
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/datalab/web/cachorro_teste (3).jpg, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-162-gc3e4e94 Python-3.10.11 torch-2.0.0+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /datalab/web/cachorro_teste (3).jpg: 416x416 1 Cachorro, 193.0ms
# Speed: 1.4ms pre-process, 193.0ms inference, 1.1ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/exp3

# %%
im_3 = Image.open('/content/yolov5/runs/detect/exp3/cachorro_teste (3).jpg')
  
im_3.show()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=416x416 at 0x7F48AEACD3C0>

# %%
# !python /content/yolov5/detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 416 --conf 0.25 --source /datalab/web/cachorro_teste\ \(4\).jpg  

#ajustar caminho
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/datalab/web/cachorro_teste (4).jpg, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-162-gc3e4e94 Python-3.10.11 torch-2.0.0+cu118 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /datalab/web/cachorro_teste (4).jpg: 416x416 1 Cachorro, 186.5ms
# Speed: 1.5ms pre-process, 186.5ms inference, 1.9ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/exp5

# %%
im_4 = Image.open('/content/yolov5/runs/detect/exp5/cachorro_teste (4).jpg')
  
im_4.show()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=416x416 at 0x7F48AEACDB40>
